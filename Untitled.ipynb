# %%
import pandas as pd

# %%
dat1 = pd.read_csv('./data/newyork_yellow_taxi_2019-01.csv')

# %%
dat1.head()
# Out:
#    Unnamed: 0  VendorID  passenger_count  trip_distance  RatecodeID  \
# 0           0         1                1            1.5           1
# 1           1         1                1            2.6           1
# 2           2         2                3            0.0           1
# 3           3         2                5            0.0           1
# 4           4         2                5            0.0           2
#
#   store_and_fwd_flag  PULocationID  DOLocationID  payment_type  fare_amount  \
# 0                  N           151           239             1          7.0
# 1                  N           239           246             1         14.0
# 2                  N           236           236             1          4.5
# 3                  N           193           193             2          3.5
# 4                  N           193           193             2         52.0
#
#    ...  pickup_date  pickup_time  dropoff_date  dropoff_time  \
# ...

# %%
dat1.shape
# Out:
# (7667792, 27)

# %%
import os
from glob import glob
import pandas as pd

data_list = glob(os.path.join('./data/', '*.csv'))

# %%
data_list
# Out:
# ['./data/newyork_yellow_taxi_2019-04.csv',
#  './data/newyork_yellow_taxi_2019-03.csv',
#  './data/newyork_yellow_taxi_2019-02.csv',
#  './data/newyork_yellow_taxi_2019-01.csv']

# %%
a = pd.read_csv(data_list[0])
b = pd.read_csv(data_list[1])

# %%
c = pd.concat([a,b])

# %%
c.head()
# Out:
#    Unnamed: 0  VendorID  passenger_count  trip_distance  RatecodeID  \
# 0           0         1                1            0.5           1
# 1           1         1                1            0.7           1
# 2           2         1                1           10.9           1
# 3           3         1                1            0.2           1
# 4           4         1                1            4.8           1
#
#   store_and_fwd_flag  PULocationID  DOLocationID  payment_type  fare_amount  \
# 0                  N           239           239             1          4.0
# 1                  N           230           100             2          4.5
# 2                  N            68           127             1         36.0
# 3                  N            68            68             2          3.5
# 4                  N            50            42             1         15.5
#
#    ...  pickup_date  pickup_time  dropoff_date  dropoff_time  \
# ...

# %%
c.columns
# Out:
# Index(['Unnamed: 0', 'VendorID', 'passenger_count', 'trip_distance',
#        'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID',
#        'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'congestion_surcharge', 'pickup_date', 'pickup_time', 'dropoff_date',
#        'dropoff_time', 'pickup_weekday_index', 'dropoff_weekday_index',
#        'pickup_holiday', 'dropoff_holiday', 'pickup_time_index',
#        'dropoff_time_index'],
#       dtype='object')
