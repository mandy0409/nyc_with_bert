# %%
import random

myList = [ 1, 2, 3, 4, 5 ]

random.shuffle(myList) # 순서 섞기 (셔플)

print(myList) # [5, 2, 1, 3, 4] 출력

# %%
from random import shuffle

a = list(range(300))

# %%
shuffle(a)

# %%
a
# Out:
# [259,
#  143,
#  53,
#  279,
#  168,
#  93,
#  188,
#  250,
#  35,
#  272,
#  4,
#  23,
#  22,
#  201,
#  7,
#  140,
#  3,
#  178,
#  10,
#  158,
#  80,
#  26,
#  286,
#  256,
#  61,
#  198,
#  15,
#  249,
#  210,
#  277,
#  187,
#  25,
#  52,
#  83,
#  16,
#  18,
#  47,
#  290,
#  123,
#  118,
#  195,
#  179,
#  266,
#  137,
#  92,
#  37,
#  132,
#  114,
#  145,
#  262,
#  170,
#  263,
#  203,
#  224,
#  192,
#  173,
#  100,
#  62,
#  135,
#  48,
#  119,
#  204,
#  232,
#  24,
#  284,
#  29,
#  9,
#  255,
#  161,
#  216,
#  257,
#  28,
#  172,
#  241,
#  134,
#  270,
#  116,
#  87,
#  127,
#  84,
#  156,
#  64,
#  49,
#  141,
#  75,
#  287,
#  292,
#  117,
#  91,
#  233,
#  14,
#  113,
#  11,
#  226,
#  65,
#  171,
#  186,
#  66,
#  13,
#  111,
#  242,
#  163,
#  219,
#  285,
#  271,
#  50,
#  295,
#  136,
#  31,
#  273,
#  89,
#  38,
#  126,
#  215,
#  77,
#  122,
#  243,
#  70,
#  252,
#  184,
#  19,
#  218,
#  166,
#  212,
#  101,
#  227,
#  68,
#  299,
#  133,
#  291,
#  254,
# ...
